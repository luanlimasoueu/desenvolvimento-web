# %%
import panel as pn

pn.extension('tabulator', sizing_mode="stretch_width")
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='4ffa512c-7522-4445-b6e4-e8e94376ce4c'>
#   <div id="cbd7772d-c62b-4a15-8d9e-1ebeaccb528c" data-root-id="4ffa512c-7522-4445-b6e4-e8e94376ce4c" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"dd1a0565-3fcc-402a-9181-8b80bbf20054":{"version":"3.3.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"4ffa512c-7522-4445-b6e4-e8e94376ce4c"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"7b70cb93-4f74-4033-bf64-3d36b96e62c7","attributes":{"plot_id":"4ffa512c-7522-4445-b6e4-e8e94376ce4c","comm_id":"1e295ea8281e4640af28cd315fa4a3c5","client_comm_id":"4aa972ec13bb4f1e9ee9f04a924f92b1"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"toggle_value1","properties":[{"name":"active_icons","kind":"Any","default":{"type":"map"}},{"name":"options","kind":"Any","default":{"type":"map","entries":[["favorite","heart"]]}},{"name":"value","kind":"Any","default":[]},{"name":"_reactions","kind":"Any","default":[]},{"name":"_base_url","kind":"Any","default":"https://tabler-icons.io/static/tabler-icons/icons/"}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"value","kind":"Any","default":null},{"name":"fill","kind":"Any","default":"none"}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"nam ...
#   var render_items = [{"docid":"dd1a0565-3fcc-402a-9181-8b80bbf20054","roots":{"4ffa512c-7522-4445-b6e4-e8e94376ce4c":"cbd7772d-c62b-4a15-8d9e-1ebeaccb528c"},"root_ids":["4ffa512c-7522-4445-b6e4-e8e94376ce4c"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
import hvplot.pandas
import holoviews as hv

hv.extension('bokeh')
# Out:
# %opts magic unavailable (pyparsing cannot be imported)
# %compositor magic unavailable (pyparsing cannot be imported)
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='e7779d82-3809-4cea-abc1-5a223a9b10d1'>
#   <div id="b90d06d8-7e68-42b4-bc57-a4514991985f" data-root-id="e7779d82-3809-4cea-abc1-5a223a9b10d1" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"31f4fb6c-5ca7-4227-a526-3f55c5f18cce":{"version":"3.3.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"e7779d82-3809-4cea-abc1-5a223a9b10d1"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"5ab77de8-fb31-48aa-b3ba-3e120c642e8b","attributes":{"plot_id":"e7779d82-3809-4cea-abc1-5a223a9b10d1","comm_id":"9db525eddb054d32b7ef679e8e31658d","client_comm_id":"834ccb52364f4c66a8bfbc065d2c0caa"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"toggle_value1","properties":[{"name":"active_icons","kind":"Any","default":{"type":"map"}},{"name":"options","kind":"Any","default":{"type":"map","entries":[["favorite","heart"]]}},{"name":"value","kind":"Any","default":[]},{"name":"_reactions","kind":"Any","default":[]},{"name":"_base_url","kind":"Any","default":"https://tabler-icons.io/static/tabler-icons/icons/"}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"value","kind":"Any","default":null},{"name":"fill","kind":"Any","default":"none"}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"nam ...
#   var render_items = [{"docid":"31f4fb6c-5ca7-4227-a526-3f55c5f18cce","roots":{"e7779d82-3809-4cea-abc1-5a223a9b10d1":"b90d06d8-7e68-42b4-bc57-a4514991985f"},"root_ids":["e7779d82-3809-4cea-abc1-5a223a9b10d1"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
def environment():
    try:
        get_ipython()
        return "notebook"
    except:
        return "server"
environment()
# Out:
# 'notebook'

# %%
PALETTE = ["#ff6f69", "#ffcc5c", "#88d8b0", ]
pn.Row(
    pn.layout.HSpacer(height=50, background=PALETTE[0]),
    pn.layout.HSpacer(height=50, background=PALETTE[1]),
    pn.layout.HSpacer(height=50, background=PALETTE[2]),
)
# Out:
# C:\Users\Luan Lima\AppData\Local\Temp\ipykernel_22348\1656622996.py:3: PanelDeprecationWarning: "HSpacer(..., background='#ff6f69')" is deprecated and will be removed in version 1.4, use "HSpacer(..., styles={'background': '#ff6f69'})" instead.
#   pn.layout.HSpacer(height=50, background=PALETTE[0]),
# C:\Users\Luan Lima\AppData\Local\Temp\ipykernel_22348\1656622996.py:4: PanelDeprecationWarning: "HSpacer(..., background='#ffcc5c')" is deprecated and will be removed in version 1.4, use "HSpacer(..., styles={'background': '#ffcc5c'})" instead.
#   pn.layout.HSpacer(height=50, background=PALETTE[1]),
# C:\Users\Luan Lima\AppData\Local\Temp\ipykernel_22348\1656622996.py:5: PanelDeprecationWarning: "HSpacer(..., background='#88d8b0')" is deprecated and will be removed in version 1.4, use "HSpacer(..., styles={'background': '#88d8b0'})" instead.
#   pn.layout.HSpacer(height=50, background=PALETTE[2]),
# Row(sizing_mode='stretch_width')
#     [0] HSpacer(background='#ff6f69', height=50, styles={'background': '#ff6f69'})
#     [1] HSpacer(background='#ffcc5c', height=50, styles={'background': '#ffcc5c'})
#     [2] HSpacer(background='#88d8b0', height=50, styles={'background': '#88d8b0'})

# %%
from bokeh.sampledata.autompg import autompg_clean as df
df.head()
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr         origin  \
# 0  18.0    8  307.0  130    3504   12.0  70  North America
# 1  15.0    8  350.0  165    3693   11.5  70  North America
# 2  18.0    8  318.0  150    3436   11.0  70  North America
# 3  16.0    8  304.0  150    3433   12.0  70  North America
# 4  17.0    8  302.0  140    3449   10.5  70  North America
#
#                         name        mfr
# 0  chevrolet chevelle malibu  chevrolet
# 1          buick skylark 320      buick
# 2         plymouth satellite   plymouth
# 3              amc rebel sst        amc
# 4                ford torino       ford

# %%
(
    df[
        (df.cyl == 4) & 
        (df.mfr.isin(['ford','chevrolet']))
    ]
    .groupby(['origin', 'cyl', 'mfr', 'yr'])['hp'].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='yr')
).head(1)
# Out:
#           origin  cyl        mfr  yr    hp
# 0  North America    4  chevrolet  71  81.0

# %%
idf = df.interactive()

# %%
cylinders = pn.widgets.IntSlider(name='Cylinders', start=4, end=8, step=2)
mfr = pn.widgets.ToggleGroup(
    name='MFR',
    options=['ford', 'chevrolet', 'honda', 'toyota', 'audi'], 
    value=['ford', 'chevrolet', 'honda', 'toyota', 'audi'],
    button_type='success')
yaxis = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['hp', 'weight'],
    button_type='success'
)

# %%
ipipeline = (
    idf[
        (idf.cyl == cylinders) & 
        (idf.mfr.isin(mfr))
    ]
    .groupby(['origin', 'mpg'])[yaxis].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='mpg')  
    .reset_index(drop=True)
)
ipipeline.head()
# Out:
# <div id='56dcf9c0-6c00-4441-a373-216181871a60'>
#   <div id="ed2db035-f0aa-4869-904f-c2fdf247b17b" data-root-id="56dcf9c0-6c00-4441-a373-216181871a60" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"1ece428d-1b0a-4931-b562-b3ec56170f09":{"version":"3.3.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"56dcf9c0-6c00-4441-a373-216181871a60","attributes":{"name":"Row01538","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"42671ad9-8045-4f04-9526-b52d83c69685","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.2/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"e7fc9831-1f8d-4e75-aae0-cff9ee0117a6","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.2/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"23f87577-8a91-44bc-a98b-7b7e0d6f8c7b","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.2/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"fb5f6f8f-19ea-44f8-b822-28cedfb6c057","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.2/dist/bundled/theme/native.css"}}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"25f9870e-73fc-4822-98e5-f5fcfb548064","attributes":{"name":"Column01535","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"42671ad9-8045-4f04-9526-b52d83c69685"},{"id":"e7fc9831-1f8d-4e75-aae0-cff9ee0117a6"},{"id":"23f87577-8a91-44bc-a98b-7b7e0d6f8c7b"},{"id":"fb5f6f8f-19ea-44f8-b822-28cedfb6c057"}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"d07fd64e-88e4-43ad-b9a8-98fe09f8c165","attributes":{"name":"Column01505","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"42671ad9-8045-4f04-9526-b52d83c69685"},{"id":"e7fc9831-1f8d-4e75-aae0-cff9ee0117a6"},{"id":"23f87577-8a91-44bc-a98b-7b7e0d6f8c7b"},{"id":"fb5f6f8f-19ea-44f8-b822-28cedfb6c057"}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"Slider","id":"68c6a1b9-932a-40c6-b4a4-22bf9f012729","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"42671ad9-8045-4f04-9526-b52d83c69685"},{"id":"23f87577-8a91-44bc-a98b-7b7e0d6f8c7b"},{"id":"fb5f6f8f-19ea-44f8-b822-28cedfb6c057"}],"margin":[5,10],"sizing_mode":"stretch_width","align":"start","title":"Cylinders","start":4,"end":8,"value":4,"step":2}},{"type":"object","name":"panel.models.widgets.CheckboxButtonGroup","id":"d44c49e7-6a73-4be1-9fc7-b41ffe931c0a","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"42671ad9-8045-4f04-9526-b52d83c69685"},{"type":"object","name":"ImportedStyleSheet","id":"c4926272-65f3-4daf-ac0b-2cb30cacdd95","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.2/dist/css/button.css"}},{"id":"23f87577-8a91-44bc-a98b-7b7e0d6f8c7b"},{"id":"fb5f6f8f-19ea-44f8-b822-28cedfb6c057"}],"margin":[5,10],"sizing_mode":"stretch_width","align":"start","labels":["ford","chevrolet","honda","toyota","audi"],"active":[0,1,2,3,4]}},{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"ce25c13c-518f-4777-98e0-599f5574909a","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base6 ...

# %%
if environment()=="server":
   theme="fast"
else:
   theme="simple"

# %%
itable = ipipeline.pipe(pn.widgets.Tabulator, pagination='remote', page_size=10)
itable
# Out:
# <div id='d22f6246-06ca-4dfe-8471-63dfe2fcb039'>
#   <div id="adcd1e29-1c59-4d86-9303-860cb5e6c02d" data-root-id="d22f6246-06ca-4dfe-8471-63dfe2fcb039" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"933cb01a-bb46-4f45-ab55-f32fc8643eea":{"version":"3.3.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"d22f6246-06ca-4dfe-8471-63dfe2fcb039","attributes":{"name":"Row01805","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"7f4034b9-dd41-48bb-956c-223915ad088f","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.2/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"8f00e24b-c2e0-4385-963b-3e2aafc33da9","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.2/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"c071c18e-e176-4e9f-a0fc-c1c56267cd90","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.2/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"3884fbdd-0855-410e-a440-f6358fddd91d","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.2/dist/bundled/theme/native.css"}}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"4baa8860-20a1-44ca-b271-ee2df92d005e","attributes":{"name":"Column01802","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"7f4034b9-dd41-48bb-956c-223915ad088f"},{"id":"8f00e24b-c2e0-4385-963b-3e2aafc33da9"},{"id":"c071c18e-e176-4e9f-a0fc-c1c56267cd90"},{"id":"3884fbdd-0855-410e-a440-f6358fddd91d"}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"ae4484c0-aba3-4bdc-9bc1-ab394aeae31e","attributes":{"name":"Column01784","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"7f4034b9-dd41-48bb-956c-223915ad088f"},{"id":"8f00e24b-c2e0-4385-963b-3e2aafc33da9"},{"id":"c071c18e-e176-4e9f-a0fc-c1c56267cd90"},{"id":"3884fbdd-0855-410e-a440-f6358fddd91d"}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"Slider","id":"4c7c850a-7945-4df3-b0c2-146b05d48334","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"7f4034b9-dd41-48bb-956c-223915ad088f"},{"id":"c071c18e-e176-4e9f-a0fc-c1c56267cd90"},{"id":"3884fbdd-0855-410e-a440-f6358fddd91d"}],"margin":[5,10],"sizing_mode":"stretch_width","align":"start","title":"Cylinders","start":4,"end":8,"value":6,"step":2}},{"type":"object","name":"panel.models.widgets.CheckboxButtonGroup","id":"556fc669-4ae7-4034-ad53-5b2fe0b9272d","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"7f4034b9-dd41-48bb-956c-223915ad088f"},{"type":"object","name":"ImportedStyleSheet","id":"8ad2de55-d87b-45cf-ba65-60fe93318327","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.2/dist/css/button.css"}},{"id":"c071c18e-e176-4e9f-a0fc-c1c56267cd90"},{"id":"3884fbdd-0855-410e-a440-f6358fddd91d"}],"margin":[5,10],"sizing_mode":"stretch_width","align":"start","labels":["ford","chevrolet","honda","toyota","audi"],"active":[2,3,4]}},{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"8adcee05-b7e9-4218-8bf5-735479d32043","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,.. ...

# %%
ihvplot = ipipeline.hvplot(x='mpg', y=yaxis, by='origin', color=PALETTE, line_width=6, height=400)
ihvplot
# Out:
# <div id='ec499726-cf87-4f49-958f-1cfb2bc728c4'>
#   <div id="dcce299f-6765-45ee-9270-b79c353bbbd8" data-root-id="ec499726-cf87-4f49-958f-1cfb2bc728c4" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"65fc9097-b26f-4a77-9f5b-4905c3eb68d2":{"version":"3.3.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"ec499726-cf87-4f49-958f-1cfb2bc728c4","attributes":{"name":"Row01966","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"677bab5f-9048-4dd0-9140-7dc1da2c7f8e","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.2/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"492ee56e-a4cb-4e02-b712-363a78c25113","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.2/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"2efcb481-5b8e-4a12-b2c4-209de1c6e387","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.2/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"fdfa27bc-9928-4554-b697-961c2f52c0cb","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.2/dist/bundled/theme/native.css"}}],"min_width":700,"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"d7100680-9784-44f6-9155-199af0d22800","attributes":{"name":"Column01963","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"677bab5f-9048-4dd0-9140-7dc1da2c7f8e"},{"id":"492ee56e-a4cb-4e02-b712-363a78c25113"},{"id":"2efcb481-5b8e-4a12-b2c4-209de1c6e387"},{"id":"fdfa27bc-9928-4554-b697-961c2f52c0cb"}],"min_width":700,"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"4660d3c7-88ab-4c16-b701-3865757b6997","attributes":{"name":"Column01946","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"677bab5f-9048-4dd0-9140-7dc1da2c7f8e"},{"id":"492ee56e-a4cb-4e02-b712-363a78c25113"},{"id":"2efcb481-5b8e-4a12-b2c4-209de1c6e387"},{"id":"fdfa27bc-9928-4554-b697-961c2f52c0cb"}],"margin":0,"sizing_mode":"stretch_width","align":"start","children":[{"type":"object","name":"Slider","id":"5d313135-11ad-44d8-ba83-d687abd7b881","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"677bab5f-9048-4dd0-9140-7dc1da2c7f8e"},{"id":"2efcb481-5b8e-4a12-b2c4-209de1c6e387"},{"id":"fdfa27bc-9928-4554-b697-961c2f52c0cb"}],"margin":[5,10],"sizing_mode":"stretch_width","align":"start","title":"Cylinders","start":4,"end":8,"value":6,"step":2}},{"type":"object","name":"panel.models.widgets.CheckboxButtonGroup","id":"d85af149-5afe-48b2-bad7-0c124aca3c13","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"677bab5f-9048-4dd0-9140-7dc1da2c7f8e"},{"type":"object","name":"ImportedStyleSheet","id":"82b78cbc-9137-4211-924a-36f1c82f228c","attributes":{"url":"https://cdn.holoviz.org/panel/1.3.2/dist/css/button.css"}},{"id":"2efcb481-5b8e-4a12-b2c4-209de1c6e387"},{"id":"fdfa27bc-9928-4554-b697-961c2f52c0cb"}],"margin":[5,10],"sizing_mode":"stretch_width","align":"start","labels":["ford","chevrolet","honda","toyota","audi"],"active":[2,3,4]}},{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"ce4fd07c-4d85-465b-bca9-aa1ed2ecc93e","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: ur ...

# %%
template = pn.template.FastListTemplate(
    title='Interactive DataFrame Dashboards with hvplot .interactive', 
    sidebar=[cylinders, 'Manufacturers', mfr, 'Y axis' , yaxis],
    main=[ihvplot.panel(), itable.panel()],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)
# template.show()
template.servable();
