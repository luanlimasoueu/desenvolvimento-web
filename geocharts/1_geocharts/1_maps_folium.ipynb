# %%
import folium
from folium import plugins

# %%
#Dados sobre as sete maravilhas do mundo antigo
sete_maravilhas_nomes = ["Grande Pirâmide de Gizé", "Jardins Suspensos da Babilônia", "Templo de Ártemis",
                        "Estátua de Zeus em Olímpia", "Mausoléu de Harnicanasso", "Colosso de Rodes", 
                         "Farol de Alexandria"]

sete_maravilhas_coordenadas = [[29.979167, 31.134722],
                              [32.531, 44.4275],
                              [37.9455, 27.3639],
                              [37.6336, 21.63],
                              [37.0336, 27.4241],
                              [36.4468, 28.2278],
                              [31.2094, 29.8856]]

# %%
sete_maravilhas_mapa = folium.Map(location=[34.3764, 27.9893], zoom_start = 5, control_scale=True)
                                 
folium.TileLayer(tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/Canvas/World_Light_Gray_Base/MapServer/tile/{z}/{y}/{x}', 
                                  attr = 'Tiles &copy; Esri &mdash; Esri, DeLorme, NAVTEQ',
                                 name = 'Esri.WorldGrayCanvas').add_to(sete_maravilhas_mapa)
folium.LayerControl().add_to(sete_maravilhas_mapa)

# %%
for i in range(len(sete_maravilhas_coordenadas)):
    coordenada = sete_maravilhas_coordenadas[i]
    maravilha = sete_maravilhas_nomes[i]
    folium.Marker(coordenada, popup=maravilha, icon=folium.Icon(icon="glyphicon glyphicon-camera", 
                                                                icon_color = "white",
                                                                color = "black", 
                                                                prefix="glyphicon")).add_to(sete_maravilhas_mapa)

# %%
sete_maravilhas_mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c9e83630a09562db4bdcad4c8986239 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c9e83630a09562db4bdcad4c8986239&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c9e83630a09562db4bdcad4c8986239 = L.map(
#                 &quot;map_7c9e83630a09562db4bdcad4c8986239&quot;,
#                 {
#                     center: [34.3764, 27.9893],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7c9e83630a09562db4bdcad4c8986239);
#
#
#
#
#
#             var tile_layer_a67c5bcad52c0234582fe9d2595ccfbd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7c9e83630a09562db4bdcad4c8986239);
#
#
#             var tile_layer_612adea7ed386696aa758f49e995374c = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/Canvas/World_Light_Gray_Base/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Esri, DeLorme, NAVTEQ&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7c9e83630a09562db4bdcad4c8986239);
#
#
#             var layer_control_a58cfe43780238d28c942bdd420e8c59 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a67c5bcad52c0234582fe9d2595ccfbd,
#                     &quot;Esri.WorldGrayCanvas&quot; : tile_layer_612adea7ed386696aa758f49e995374c,
#                 },
#                 overlays :  {
#                 },
#             };
#             L.control.layers(
#                 layer_control_a58cfe43780238d28c942bdd420e8c59.base_layers,
#                 layer_control_a58cfe43780238d28c942bdd420e8c59.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_7c9e83630a09562db4bdcad4c8986239);
#             tile_layer_612adea7ed386696aa758f49e995374c.remove();
#
#
#             var marker_c3caa2a36f30c7cf67c1b88026b7da84 = L.marker(
#                 [29.979167, 31.134722],
#                 {}
#             ).addTo(map_7c9e83630a09562db4bdcad4c8986239);
#
#
#             var icon_3e8cb6e27fea01b4e0eacf62bacee3f7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c3caa2a36f30c7cf67c1b88026b7da84.setIcon(icon_3e8cb6e27fea01b4e0eacf62bacee3f7);
#
#
#         var popup_333cc0076d7f1bcf8f4dfc8c4755a5a5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_59ca9736b87447a336197f58ed544f01 = $(`&lt;div id=&quot;html_59ca9736b87447a336197f58ed544f01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Grande Pirâmide de Gizé&lt;/div&gt;`)[0];
#                 popup_333cc0076d7f1bcf8f4dfc8c4755a5a5.setContent(html_59ca9736b87447a336197f58ed544f01);
#
#
#
#         marker_c3caa2a36f30c7cf67c1b88026b7da84.bindPopup(popup_333cc0076d7f1bcf8f4dfc8c4755a5a5)
#         ;
#
#
#
#
#             var marker_89e3219befeda9d72c0d1faef0b0bb8b = L.marker(
#                 [32.531, 44.4275],
#                 {}
#             ).addTo(map_7c9e83630a09562db4bdcad4c8986239);
#
#
#             var icon_529916caa987578186f154cb6f8004fa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_89e3219befeda9d72c0d1faef0b0bb8b.setIcon(icon_529916caa987578186f154cb6f8004fa);
#
#
#         var popup_a13bb55dda5d8eb05cf7ad64ab0d8f8a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_908a49f453c21226417b7ecbe85869c1 = $(`&lt;div id=&quot;html_908a49f453c21226417b7ecbe85869c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jardins Suspensos da Babilônia&lt;/div&gt;`)[0];
#                 popup_a13bb55dda5d8eb05cf7ad64ab0d8f8a.setContent(html_908a49f453c21226417b7ecbe85869c1);
#
#
#
#         marker_89e3219befeda9d72c0d1faef0b0bb8b.bindPopup(popup_a13bb55dda5d8eb05cf7ad64ab0d8f8a)
#         ;
#
#
#
#
#             var marker_8373fbf1f4ce8bce99
